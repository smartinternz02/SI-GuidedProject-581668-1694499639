# %% [markdown]
# > ## **Task 2**
# * Name: DEVANSHU GUPTA
# * Reg.No.: 21BCE0597
# * Email id: devanshu.gupta2021@vitstudent.ac.in
# * Github Link: https://github.com/devanshu0602/Applied-Data-Science/tree/main/Task%202
# * Branch: CSE
# * Campus: VIT Vellore
# * Learning Track: AI & ML in collab. with Google (Applied Data Science)
# * Batch: Evening (6pm - 8pm)

# %% [markdown]
# ## Task 2.1 -> Download the dataset: [Dataset](https://www.kaggle.com/datasets/mohamedafsal007/house-price-dataset-of-india)

# %% [markdown]
# ## Task 2.2 -> Load the dataset.

# %%
# Importing the required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Loading the dataset
df = pd.read_csv('/content/House Price India.csv')
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %% [markdown]
# ## Task 2.3 ->  Perform the Below Visualizations.
# * Uni - variate Analysis
# * Bi - variate Analysis
# * Multi - variate Analysis

# %% [markdown]
# ### Uni-variate Analysis

# %%
# Scatter plot for the 'Lattitude' column
plt.figure(figsize=[15,15])

sns.scatterplot(df['Lattitude'])

plt.title('Lattitude of each houses')
# Out:
# Text(0.5, 1.0, 'Lattitude of each houses')

# %%
# Line plot for the 'Price' column
plt.figure(figsize=[15,15])

sns.lineplot(df['Price'])

plt.title('Price of each house')
# Out:
# Text(0.5, 1.0, 'Price of each house')

# %%
# Pie chart for the 'Number of schools nearby' column
plt.pie(
    df.head(10)['Number of schools nearby'],
    labels = df.head(10)['id'],
    autopct = '%.1f%%'
)

plt.title('Number of Schools nearby - for the first 10 houses')
# Out:
# Text(0.5, 1.0, 'Number of Schools nearby - for the first 10 houses')

# %% [markdown]
# ### Bi-variate Analysis

# %%
# Segmented Bar graph of 'Longitude' and 'Lattitude' w.r.t the 'id'
plt.figure(figsize = [15,15])

plt.bar(df['id'], df['Lattitude'], label="Lattitude", width=0.5, color='y')
plt.bar(df['id'], df['Longitude'], label="Longitude", width=0.5, color='g')

plt.xlabel("ID of the house")
plt.ylabel("Longitude & Lattitude")
plt.legend()
plt.title('Lattitude & Longitude for each house')
# Out:
# Text(0.5, 1.0, 'Lattitude & Longitude for each house')
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Lineplot of 'living_area_renov' of each house
plt.figure(figsize = [15,15])

sns.lineplot(
    x=df['id'],
    y=df['living_area_renov']
)

plt.xlabel("ID of the house")
plt.ylabel("Living Area Renov")
plt.title('Living Area')
# Out:
# Text(0.5, 1.0, 'Living Area')

# %% [markdown]
# ### Multi-variate Analysis

# %%
# Heatmap
plt.figure(figsize = [20,20])

sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Task 2.4 -> Perform descriptive statistics on the dataset.

# %%
# Performing the descriptive statistics on the dataset
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %% [markdown]
# ## Task 2.5 -> Handle the Missing values.

# %%
# Checking if there are any null values
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %% [markdown]
# --> We can see that there are no null/missing values and hence, we don't need to perform any extra steps.
